# %%
import pandas as pd

# %%
df = pd.read_csv('data_cocktails.csv')

# %%
df
# Out:
#       Unnamed: 0                              strDrink   strCategory  \
# 0              0  '57 Chevy with a White License Plate      Cocktail
# 1              1  '57 Chevy with a White License Plate      Cocktail
# 2              2                        1-900-FUK-MEUP          Shot
# 3              3                        1-900-FUK-MEUP          Shot
# 4              4                        1-900-FUK-MEUP          Shot
# ...          ...                                   ...           ...
# 1776        1776                             Zorbatini      Cocktail
# 1777        1777                             Zorbatini      Cocktail
# 1778        1778                                 Zorro  Coffee / Tea
# 1779        1779                                 Zorro  Coffee / Tea
# 1780        1780                                 Zorro  Coffee / Tea
#
#                  strGlass         strIngredients        Alc_type Basic_taste  \
# ...

# %%
merge_ingredients = {
    'Absolut Vodka': 'Vodka',
    'Anis': 'Anisette',
    'Baileys Irish Cream': "Bailey'S Irish Cream",
    'Brandy Plain': "Brandy",
    'Cherries': 'Cherry',
    'Cider Hard': 'Cider',
    'Coffee Cold': 'Coffee',
    'Coffee Hot': 'Coffee',
    'Dark Rum Jamaican': 'Dark Rum',
    'Fresh Lemon Juice': 'Lemon Juice',
    'Fresh Lime Juice': 'Lime Juice',
    'Lemon Juice Sweetened': 'Lemon Juice',
    'Lemonade Cold': 'Lemonade',
    'Lemonade Frozen': 'Lemonade',
    'Lime Juice Fresh': 'Lime Juice',
    'Light Rum Jamaican': 'Light Rum',
    'Nutmeg Grated': 'Nutmeg',
    'Nutmeg Ground': 'Nutmeg',
    'Orange Juice Frozen': 'Orange Juice',
    'Rub Light Or Dark': 'Rum',
    'Rum Jamaican': 'Rum',
    'Powdered Sugar': 'Sugar',
    'Sugar Superfine': 'Sugar',
    'Tonic Water Schweppes': 'Tonic Water',
    'Vodka Smirnoff': 'Vodka',
    'Vodka Smirnoff Red Label': 'Vodka',
}

# %%
replace_glass = {
    'Champagne flute': 'Champagne Flute',
    'Cocktail glass': 'Cocktail Glass',
    'Coffee mug': 'Coffee Mug',
    'Collins glass': 'Collins Glass',
    'Highball glass': 'Highball Glass',
    'Margarita/Coupette glass': 'Margarita glass',
    'Old-Fashioned glass': 'Old-fashioned glass',
    'Punch bowl': 'Punch Bowl',
    'Shot glass': 'Shot Glass',
}

# %%
df.replace(replace_glass).replace(merge_ingredients).to_csv('data_cocktails_cleaned.csv', index=False)

# %%
df.strDrink.unique()
# Out:
# array(["'57 Chevy with a White License Plate", '1-900-FUK-MEUP',
#        '110 in the shade', '151 Florida Bushwacker', '155 Belmont',
#        '24k nightmare', '252', '3 Wise Men',
#        '3-Mile Long Island Iced Tea', '410 Gone', '50/50', '501 Blue',
#        '69 Special', '747', '9 1/2 Weeks', 'A Day at the Beach',
#        'A Furlong Too Late', "A Gilligan's Island",
#        'A Night In Old Mandalay', 'A Piece of Ass', 'A Splash of Nash',
#        'A True Amaretto Sour', 'A midsummernight dream', 'A. J.',
#        'A.D.M. (After Dinner Mint)', 'A1', 'ABC', 'ACID', 'AT&T',
#        'Abbey Cocktail', 'Abbey Martini', 'Abilene', 'Absolut Evergreen',
#        'Absolut Sex', 'Absolut Stress #2', 'Absolut Summertime',
#        'Absolut limousine', 'Absolutely Cranberry Smash',
#        'Absolutely Fabulous', 'Absolutly Screwed Up', 'Acapulco', 'Ace',
#        'Adam', 'Adam & Eve', 'Adam Bomb', 'Adam Sunrise', 'Addington',
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=08e32eae-680f-4766-bfea-eabbd1bdf534' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
