# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("all_drinks.csv")
df1
# Out:
#      Unnamed: 0                              strDrink         dateModified  \
# 0             0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1             1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2             2                      110 in the shade  2016-02-03 14:51:57
# 3             3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4             4                           155 Belmont  2016-10-05 12:36:28
# ..          ...                                   ...                  ...
# 541         541                       Zippy's Revenge  2017-01-28 16:18:33
# 542         542                        Zizi Coin-coin  2017-01-28 16:25:52
# 543         543                                Zoksel  2017-01-28 16:28:50
# 544         544                             Zorbatini  2017-01-28 16:32:35
# 545         545                                 Zorro  2017-01-28 16:34:43
#
#      idDrink strAlcoholic           strCategory  \
# 0      14029    Alcoholic              Cocktail
# 1      15395    Alcoholic                  Shot
# 2      15423    Alcoholic                  Beer
# 3      14588    Alcoholic  Milk / Float / Shake
# 4      15346    Alcoholic              Cocktail
# ..       ...          ...                   ...
# 541    14065    Alcoholic              Cocktail
# 542    14594    Alcoholic   Punch / Party Drink
# 543    15691    Alcoholic     Soft Drink / Soda
# 544    16963    Alcoholic              Cocktail
# 545    15328    Alcoholic          Coffee / Tea
#
#                                          strDrinkThumb  \
# 0    http://www.thecocktaildb.com/images/media/drin...
# 1    http://www.thecocktaildb.com/images/media/drin...
# 2    http://www.thecocktaildb.com/images/media/drin...
# 3    http://www.thecocktaildb.com/images/media/drin...
# 4    http://www.thecocktaildb.com/images/media/drin...
# ..                                                 ...
# 541  http://www.thecocktaildb.com/images/media/drin...
# 542  http://www.thecocktaildb.com/images/media/drin...
# 543  http://www.thecocktaildb.com/images/media/drin...
# 544  http://www.thecocktaildb.com/images/media/drin...
# 545  http://www.thecocktaildb.com/images/media/drin...
#
#                      strGlass strIBA  strIngredient1  ... strMeasure15  \
# 0              Highball glass    NaN  Creme de Cacao  ...          NaN
# 1         Old-fashioned glass    NaN  Absolut Kurant  ...          NaN
# 2                  Beer Glass    NaN           Lager  ...          NaN
# 3                    Beer mug    NaN      Malibu rum  ...          NaN
# 4            White wine glass    NaN        Dark rum  ...          NaN
# ..                        ...    ...             ...  ...          ...
# 541       Old-fashioned glass    NaN        Amaretto  ...          NaN
# 542  Margarita/Coupette glass    NaN       Cointreau  ...          NaN
# 543              Beer pilsner    NaN            Beer  ...          NaN
# 544            Cocktail glass    NaN           Vodka  ...          NaN
# 545                Coffee Mug    NaN         Sambuca  ...          NaN
#
#     strMeasure2      strMeasure3  strMeasure4  strMeasure5  strMeasure6  \
# 0         1 oz
# 1       1/4 oz           1/4 oz       1/4 oz       1/4 oz       1/4 oz
# 2       1.5 oz
# 3       1/2 oz   1/2 oz Bacardi         1 oz         1 oz         3 oz
# 4      2 shots           1 shot       1 shot
# ..          ...              ...          ...          ...          ...
# 541       2 oz       4 oz Grape
# 542       2 cl           cubes\n    or lime\n           \n           \n
# 543          \n               \n      slice\n           \n           \n
# 544     1/4 oz
# 545       2 cl             2 cl
#
#     strMeasure7 strMeasure8 strMeasure9 strVideo
# 0                       NaN         NaN      NaN
# 1       1/2 oz      1/4 oz                   NaN
# 2                       NaN         NaN      NaN
# 3         1 oz       1 cup                   NaN
# 4                                            NaN
# ..          ...         ...         ...      ...
# 541                                 NaN      NaN
# 542          \n          \n          \n      NaN
# 543          \n          \n          \n      NaN
# 544                     NaN         NaN      NaN
# 545                                 NaN      NaN
#
# [546 rows x 41 columns]

# %%
df2 = pd.read_csv("cocktail_popularity.csv")
df2
# Out:
#       Unnamed: 0 place                name  year     month  visitors
# 0              0    1            '57 Chevy  2001     total      1512
# 1              1    2           Caipirinha  2001     total      1301
# 2              2    3   Long Island Icetea  2001     total       903
# 3              3    4          Piña Colada  2001     total       601
# 4              4    5          Tall Blonde  2001     total       573
# ...          ...   ...                 ...   ...       ...       ...
# 2395           5    6      Schwanzlstürzer  2020  Dezember        47
# 2396           6    7    Omas offenes Bein  2020  Dezember        47
# 2397           7    8         Baby Aspirin  2020  Dezember        42
# 2398           8    9              Mai Tai  2020  Dezember        42
# 2399           9   10               Zombie  2020  Dezember        40
#
# [2400 rows x 6 columns]

# %%
df3 = pd.read_csv("data_cocktails.csv")
df3
# Out:
#       Unnamed: 0                              strDrink   strCategory  \
# 0              0  '57 Chevy with a White License Plate      Cocktail
# 1              1  '57 Chevy with a White License Plate      Cocktail
# 2              2                        1-900-FUK-MEUP          Shot
# 3              3                        1-900-FUK-MEUP          Shot
# 4              4                        1-900-FUK-MEUP          Shot
# ...          ...                                   ...           ...
# 1776        1776                             Zorbatini      Cocktail
# 1777        1777                             Zorbatini      Cocktail
# 1778        1778                                 Zorro  Coffee / Tea
# 1779        1779                                 Zorro  Coffee / Tea
# 1780        1780                                 Zorro  Coffee / Tea
#
#                  strGlass         strIngredients        Alc_type Basic_taste  \
# 0          Highball glass   Creme De Cacao White  Creamy Liqueur         NaN
# 1          Highball glass                  Vodka           Vodka         NaN
# 2     Old-fashioned glass          Grand Marnier      Triple Sec         NaN
# 3     Old-fashioned glass   Midori Melon Liqueur   Sweet Liqueur         NaN
# 4     Old-fashioned glass             Malibu Rum             Rum         NaN
# ...                   ...                    ...             ...         ...
# 1776       Cocktail glass                  Vodka           Vodka         NaN
# 1777       Cocktail glass                   Ouzo            Ouzo         NaN
# 1778           Coffee Mug                Sambuca         Sambuca         NaN
# 1779           Coffee Mug   Bailey'S Irish Cream  Creamy Liqueur         NaN
# 1780           Coffee Mug  White Creme De Menthe   Sweet Liqueur         NaN
#
#                                         strInstructions     strMeasures  \
# 0     1. Fill a rocks glass with ice 2.add white cre...      1 oz white
# 1     1. Fill a rocks glass with ice 2.add white cre...            1 oz
# 2     Shake ingredients in a mixing tin filled with ...          1/4 oz
# 3     Shake ingredients in a mixing tin filled with ...          1/4 oz
# 4     Shake ingredients in a mixing tin filled with ...          1/4 oz
# ...                                                 ...             ...
# 1776  Prepare like a Martini. Garnish with a green o...  1 1/4 oz stoli
# 1777  Prepare like a Martini. Garnish with a green o...          1/4 oz
# 1778  add all and pour black coffee and add whipped ...            2 cl
# 1779  add all and pour black coffee and add whipped ...            2 cl
# 1780  add all and pour black coffee and add whipped ...            2 cl
#
#       Value_ml  Value_gr Garnish_amount Garnish_type
# 0         30.0       NaN            NaN          NaN
# 1         30.0       NaN            NaN          NaN
# 2          7.5       NaN            NaN          NaN
# 3          7.5       NaN            NaN          NaN
# 4          7.5       NaN            NaN          NaN
# ...        ...       ...            ...          ...
# 1776      37.5       NaN            NaN          NaN
# 1777       7.5       NaN            NaN          NaN
# 1778      20.0       NaN            NaN          NaN
# 1779      20.0       NaN            NaN          NaN
# 1780      20.0       NaN            NaN          NaN
#
# [1781 rows x 13 columns]

# %%
df3["strDrink"].value_counts()
# Out:
# Egg Nog #4                     11
# 3-Mile Long Island Iced Tea     9
# 1-900-FUK-MEUP                  8
# Chocolate Monkey                8
# Arizona Twister                 8
#                                ..
# Iced Coffee Fillip              2
# Big Red                         2
# Stinger                         2
# Screwdriver                     2
# Cream Soda                      2
# Name: strDrink, Length: 473, dtype: int64

# %%
df4 = pd.read_csv("hotaling_cocktails.csv")
df4
# Out:
#                  Cocktail Name            Bartender           Bar/Company  \
# 0               Flor de Amaras       Kelly McCarthy                   NaN
# 1              The Happy Place    Elizabeth Montana       Forgery & Verso
# 2       Bon Voyage Pisco Punch          Jon Morales                   NaN
# 3    Still Life of a Pineapple      Daniel Braganca               Backbar
# 4          The Bittered Valley           Nik Virrey                   NaN
# ..                         ...                  ...                   ...
# 682         The Negroni Bianco                  NaN                   NaN
# 683           Match Grip Julep       Jarred Weigand           Death & Co.
# 684             The Dry Cruise  Jacyara de Oliveira  Rob Roy, The Hideout
# 685                   Red Hook     Patrick Halloran         Henrietta Red
# 686                 Union Jack           Jason Patz      Union Lodge No.1
#
#           Location                                        Ingredients  \
# 0           Boston  1.5 oz Mezcal, 1 oz Hibiscus Simple Syrup*, .5...
# 1    San Francisco  2 oz Junipero Gin, .75 oz House-made Cranberry...
# 2    San Francisco  1500 ml BarSol Selecto Italia Pisco, 750 ml Le...
# 3       Somerville  1.5 oz BarSol Primero Quebranta Pisco, .75 oz ...
# 4          Seattle  1.25 oz Luxardo Maraschino Liqueur, 4 drops Ac...
# ..             ...                                                ...
# 682            NaN  1.5 oz Luxardo Bitter Bianco, .75 oz Tempus Fu...
# 683       New York  1.5 oz H by HINE, .5 oz Jamaican Rum, 1 tsp Ca...
# 684        Seattle  1 oz Luxardo Bitter Bianco, 1 oz Lustau Oloros...
# 685      Nashville  2 oz Rye Whiskey, 5 oz Punt e Mes, .5 oz Luxar...
# 686         Denver  .75 oz Luxardo Maraschino Liqueur, .75 oz Gree...
#
#                                        Garnish   Glassware  \
# 0                              Marigold Petals         NaN
# 1    Dehydrated Lemon Wheel, Sprig of Rosemary         NaN
# 2                                          NaN  Punch Bowl
# 3                                          NaN         NaN
# 4                                          NaN         NaN
# ..                                         ...         ...
# 682                                        NaN         NaN
# 683                                        NaN         NaN
# 684                       Edible Flower, Straw         NaN
# 685                                        NaN         NaN
# 686                                        NaN         NaN
#
#                                            Preparation  \
# 0    *Hibiscus Simple Syrup:\n1:1 w/ a cup of dried...
# 1    *House-made Cranberry syrup: \n-- 2 cups Fresh...
# 2    *Pineapple Gomme: \nMix equal parts (1.5 cups)...
# 3    *Pineapple Syrup:\n<em>Equal parts pineapple b...
# 4    1st glass ingredients:\nLuxardo Maraschino, Ac...
# ..                                                 ...
# 682                                                NaN
# 683                                                NaN
# 684                                                NaN
# 685                                                NaN
# 686                                                NaN
#
#                                                 Notes
# 0                                                 NaN
# 1    Junipero Gin 20th Anniversary Signature Cocktail
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 682                                               NaN
# 683                                               NaN
# 684                                               NaN
# 685                                               NaN
# 686                                               NaN
#
# [687 rows x 9 columns]

# %%
df1.describe()
# Out:
#        Unnamed: 0       idDrink  strIngredient13  strIngredient14  \
# count  546.000000    546.000000              0.0              0.0
# mean   272.500000  13775.919414              NaN              NaN
# std    157.760895   2109.605005              NaN              NaN
# min      0.000000  11000.000000              NaN              NaN
# 25%    136.250000  12055.500000              NaN              NaN
# 50%    272.500000  13069.000000              NaN              NaN
# 75%    408.750000  15666.000000              NaN              NaN
# max    545.000000  17230.000000              NaN              NaN
#
#        strIngredient15  strVideo
# count              0.0       0.0
# mean               NaN       NaN
# std                NaN       NaN
# min                NaN       NaN
# 25%                NaN       NaN
# 50%                NaN       NaN
# 75%                NaN       NaN
# max                NaN       NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 41 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       546 non-null    int64
#  1   strDrink         546 non-null    object
#  2   dateModified     545 non-null    object
#  3   idDrink          546 non-null    int64
#  4   strAlcoholic     545 non-null    object
#  5   strCategory      546 non-null    object
#  6   strDrinkThumb    546 non-null    object
#  7   strGlass         546 non-null    object
#  8   strIBA           71 non-null     object
#  9   strIngredient1   546 non-null    object
#  10  strIngredient10  3 non-null      object
#  11  strIngredient11  3 non-null      object
#  12  strIngredient12  1 non-null      object
#  13  strIngredient13  0 non-null      float64
#  14  strIngredient14  0 non-null      float64
#  15  strIngredient15  0 non-null      float64
#  16  strIngredient2   546 non-null    object
#  17  strIngredient3   461 non-null    object
#  18  strIngredient4   294 non-null    object
#  19  strIngredient5   166 non-null    object
#  20  strIngredient6   78 non-null     object
#  21  strIngredient7   25 non-null     object
#  22  strIngredient8   15 non-null     object
#  23  strIngredient9   6 non-null      object
#  24  strInstructions  545 non-null    object
#  25  strMeasure1      546 non-null    object
#  26  strMeasure10     144 non-null    object
#  27  strMeasure11     66 non-null     object
#  28  strMeasure12     20 non-null     object
#  29  strMeasure13     12 non-null     object
#  30  strMeasure14     4 non-null      object
#  31  strMeasure15     3 non-null      object
#  32  strMeasure2      543 non-null    object
#  33  strMeasure3      539 non-null    object
#  34  strMeasure4      527 non-null    object
#  35  strMeasure5      520 non-null    object
#  36  strMeasure6      523 non-null    object
#  37  strMeasure7      522 non-null    object
#  38  strMeasure8      414 non-null    object
#  39  strMeasure9      257 non-null    object
#  40  strVideo         0 non-null      float64
# dtypes: float64(4), int64(2), object(35)
# memory usage: 175.0+ KB

# %%
c
# Out:
# Unnamed: 0           0
# strDrink             0
# dateModified         1
# idDrink              0
# strAlcoholic         1
# strCategory          0
# strDrinkThumb        0
# strGlass             0
# strIBA             475
# strIngredient1       0
# strIngredient10    543
# strIngredient11    543
# strIngredient12    545
# strIngredient13    546
# strIngredient14    546
# strIngredient15    546
# strIngredient2       0
# strIngredient3      85
# strIngredient4     252
# strIngredient5     380
# strIngredient6     468
# strIngredient7     521
# strIngredient8     531
# strIngredient9     540
# strInstructions      1
# strMeasure1          0
# strMeasure10       402
# strMeasure11       480
# strMeasure12       526
# strMeasure13       534
# strMeasure14       542
# strMeasure15       543
# strMeasure2          3
# strMeasure3          7
# strMeasure4         19
# strMeasure5         26
# strMeasure6         23
# strMeasure7         24
# strMeasure8        132
# strMeasure9        289
# strVideo           546
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2400 non-null   int64
#  1   place       2400 non-null   object
#  2   name        2400 non-null   object
#  3   year        2400 non-null   int64
#  4   month       2400 non-null   object
#  5   visitors    2400 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 112.6+ KB

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# place         0
# name          0
# year          0
# month         0
# visitors      0
# dtype: int64

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1781 non-null   int64
#  1   strDrink         1781 non-null   object
#  2   strCategory      1781 non-null   object
#  3   strGlass         1781 non-null   object
#  4   strIngredients   1781 non-null   object
#  5   Alc_type         931 non-null    object
#  6   Basic_taste      850 non-null    object
#  7   strInstructions  1781 non-null   object
#  8   strMeasures      1664 non-null   object
#  9   Value_ml         1351 non-null   float64
#  10  Value_gr         173 non-null    float64
#  11  Garnish_amount   149 non-null    object
#  12  Garnish_type     150 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 181.0+ KB

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0            0
# strDrink              0
# strCategory           0
# strGlass              0
# strIngredients        0
# Alc_type            850
# Basic_taste         931
# strInstructions       0
# strMeasures         117
# Value_ml            430
# Value_gr           1608
# Garnish_amount     1632
# Garnish_type       1631
# dtype: int64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687 entries, 0 to 686
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Cocktail Name  687 non-null    object
#  1   Bartender      452 non-null    object
#  2   Bar/Company    270 non-null    object
#  3   Location       342 non-null    object
#  4   Ingredients    687 non-null    object
#  5   Garnish        523 non-null    object
#  6   Glassware      485 non-null    object
#  7   Preparation    642 non-null    object
#  8   Notes          151 non-null    object
# dtypes: object(9)
# memory usage: 48.4+ KB

# %%
df4.isnull().sum()
# Out:
# Cocktail Name      0
# Bartender        235
# Bar/Company      417
# Location         345
# Ingredients        0
# Garnish          164
# Glassware        202
# Preparation       45
# Notes            536
# dtype: int64

# %%
df1["strDrinkThumb"][200]
# Out:
# 'http://www.thecocktaildb.com/images/media/drink/anhof61504366173.jpg'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=08e32eae-680f-4766-bfea-eabbd1bdf534' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
