# %%
import pandas as pd
df = pd.read_csv('data_cocktails_cleaned.csv')

# %%
df
# Out:
#       Unnamed: 0                              strDrink   strCategory  \
# 0              0  '57 Chevy with a White License Plate      Cocktail
# 1              1  '57 Chevy with a White License Plate      Cocktail
# 2              2                        1-900-FUK-MEUP          Shot
# 3              3                        1-900-FUK-MEUP          Shot
# 4              4                        1-900-FUK-MEUP          Shot
# ...          ...                                   ...           ...
# 1776        1776                             Zorbatini      Cocktail
# 1777        1777                             Zorbatini      Cocktail
# 1778        1778                                 Zorro  Coffee / Tea
# 1779        1779                                 Zorro  Coffee / Tea
# 1780        1780                                 Zorro  Coffee / Tea
#
#                  strGlass         strIngredients        Alc_type Basic_taste  \
# 0          Highball Glass   Creme De Cacao White  Creamy Liqueur         NaN
# 1          Highball Glass                  Vodka           Vodka         NaN
# 2     Old-fashioned glass          Grand Marnier      Triple Sec         NaN
# 3     Old-fashioned glass   Midori Melon Liqueur   Sweet Liqueur         NaN
# 4     Old-fashioned glass             Malibu Rum             Rum         NaN
# ...                   ...                    ...             ...         ...
# 1776       Cocktail Glass                  Vodka           Vodka         NaN
# 1777       Cocktail Glass                   Ouzo            Ouzo         NaN
# 1778           Coffee Mug                Sambuca         Sambuca         NaN
# 1779           Coffee Mug   Bailey'S Irish Cream  Creamy Liqueur         NaN
# 1780           Coffee Mug  White Creme De Menthe   Sweet Liqueur         NaN
#
#                                         strInstructions     strMeasures  \
# 0     1. Fill a rocks glass with ice 2.add white cre...      1 oz white
# 1     1. Fill a rocks glass with ice 2.add white cre...            1 oz
# 2     Shake ingredients in a mixing tin filled with ...          1/4 oz
# 3     Shake ingredients in a mixing tin filled with ...          1/4 oz
# 4     Shake ingredients in a mixing tin filled with ...          1/4 oz
# ...                                                 ...             ...
# 1776  Prepare like a Martini. Garnish with a green o...  1 1/4 oz stoli
# 1777  Prepare like a Martini. Garnish with a green o...          1/4 oz
# 1778  add all and pour black coffee and add whipped ...            2 cl
# 1779  add all and pour black coffee and add whipped ...            2 cl
# 1780  add all and pour black coffee and add whipped ...            2 cl
#
#       Value_ml  Value_gr Garnish_amount Garnish_type
# 0         30.0       NaN            NaN          NaN
# 1         30.0       NaN            NaN          NaN
# 2          7.5       NaN            NaN          NaN
# 3          7.5       NaN            NaN          NaN
# 4          7.5       NaN            NaN          NaN
# ...        ...       ...            ...          ...
# 1776      37.5       NaN            NaN          NaN
# 1777       7.5       NaN            NaN          NaN
# 1778      20.0       NaN            NaN          NaN
# 1779      20.0       NaN            NaN          NaN
# 1780      20.0       NaN            NaN          NaN
#
# [1781 rows x 13 columns]

# %%
ingredients_type = {}
for ingredient in df['strIngredients'].unique():
    # aggregate unique Alc_type
    alc_type = df[df['strIngredients'] == ingredient]['Alc_type'].unique()
    # there should only be 1 Alc_type for each ingredient
    assert len(alc_type) == 1
    # check if Alc_type is a valid string
    if type(alc_type[0]) == str:
        ingredients_type[ingredient] = "spirit"
    else: # not a spirit if Alc_type is nan
        # aggregate unique Garnish_type
        garnish_type = df[df['strIngredients'] == ingredient]['Garnish_type'].unique()
        # count as mixer if it's "top up" (e.g. coca cola)
        if "top up" in garnish_type:
            ingredients_type[ingredient] = "mixer"
        # check if Garnish_type is nan
        elif len(garnish_type) == 1 and type(garnish_type[0]) != str:
            ingredients_type[ingredient] = "mixer"
        else:
            ingredients_type[ingredient] = "garnish"

# %%
ingredients_type
# Out:
# {'Creme De Cacao White': 'spirit',
#  'Vodka': 'spirit',
#  'Grand Marnier': 'spirit',
#  'Midori Melon Liqueur': 'spirit',
#  'Malibu Rum': 'spirit',
#  'Amaretto': 'spirit',
#  'Cranberry Juice': 'mixer',
#  'Pineapple Juice': 'mixer',
#  'Chambord Raspberry Liqueur': 'spirit',
#  'Absolut Kurant': 'spirit',
#  'Tequila': 'spirit',
#  'Lager': 'spirit',
#  'Dark Creme De Cacao': 'spirit',
#  'Coconut Liqueur': 'spirit',
#  'Light Rum': 'spirit',
#  'Milk': 'mixer',
#  'Cointreau': 'spirit',
#  'Vanilla Ice-Cream': 'mixer',
#  '151 Proof Rum': 'spirit',
#  'Orange Juice': 'mixer',
#  'Dark Rum': 'spirit',
#  'Jägermeister': 'spirit',
#  'Goldschlager': 'spirit',
#  'Rumple Minze': 'spirit',
#  'Wild Turkey': 'spirit',
#  'Jim Beam': 'spirit',
#  'Johnnie Walker': 'spirit',
#  'Jack Daniels': 'spirit',
#  'Coca-Cola': 'mixer',
#  'Sweet And Sour': 'mixer',
#  'Triple Sec': 'spirit',
#  'Bitters': 'spirit',
#  'Lemon': 'garnish',
#  'Gin': 'spirit',
#  'Peach Vodka': 'spirit',
#  'Vanilla Vodka': 'spirit',
#  'Sour Mix': 'mixer',
#  'Blueberry Schnapps': 'spirit',
#  'Blue Curacao': 'spirit',
#  '7-Up': 'mixer',
#  'Gin Dry': 'spirit',
#  'Lemon Juice': 'mixer',
#  "Bailey'S Irish Cream": 'spirit',
#  'Kahlua': 'spirit',
#  'Frangelico': 'spirit',
#  'Orange Curacao': 'spirit',
#  'Strawberry Liqueur': 'spirit',
#  'Absolut Citron': 'spirit',
#  'Grenadine': 'mixer',
#  'Coconut Rum': 'spirit',
#  'Ginger Beer': 'mixer',
#  'Lemon Peel': 'garnish',
#  'Peach Schnapps': 'spirit',
#  'Ginger Ale': 'mixer',
#  'Añejo Rum': 'spirit',
#  'Southern Comfort': 'spirit',
#  'Creme De Banane': 'spirit',
#  'Soda Water': 'mixer',
#  'Maraschino Cherry': 'garnish',
#  'Strawberries': 'mixer',
#  'Kirschwasser': 'spirit',
#  'Schweppes Russchian': 'mixer',
#  'Grapefruit Juice': 'mixer',
#  'Applejack': 'spirit',
#  'Hot Chocolate': 'mixer',
#  'White Creme De Menthe': 'spirit',
#  'Cognac': 'spirit',
#  'Tonic Water': 'mixer',
#  'Orange': 'garnish',
#  'Orange Bitters': 'spirit',
#  'Cherry': 'garnish',
#  'Sweet Vermouth': 'spirit',
#  'Angostura Bitters': 'spirit',
#  'Peach Nectar': 'mixer',
#  'Pisang Ambon': 'spirit',
#  'Bitter Lemon': 'spirit',
#  'Sprite': 'mixer',
#  'Lime Juice': 'mixer',
#  'Champagne': 'spirit',
#  'Mint': 'garnish',
#  'Egg White': 'mixer',
#  'Sugar': 'garnish',
#  'Heavy Cream': 'mixer',
#  'Creme De Cassis': 'spirit',
#  'Salt': 'garnish',
#  'Fruit Juice': 'mixer',
#  'Rum': 'spirit',
#  'Water': 'mixer',
#  'Lemonade': 'mixer',
#  'Dry Vermouth': 'spirit',
#  'Vermouth': 'spirit',
#  'Sugar Syrup': 'mixer',
#  'Sherry Dry': 'spirit',
#  'Club Soda': 'mixer',
#  'Strawberry Schnapps': 'spirit',
#  'Scotch': 'spirit',
#  'Apricot Brandy': 'spirit',
#  'Lime': 'garnish',
#  'Peppermint Schnapps': 'spirit',
#  'Cream': 'mixer',
#  'Coffee': 'mixer',
#  'Sloe Gin': 'spirit',
#  'Yellow Chartreuse': 'spirit',
#  'Nutmeg': 'garnish',
#  'Light Cream': 'mixer',
#  'Lemon Vodka': 'spirit',
#  'Blended Whiskey': 'spirit',
#  'Bourbon': 'spirit',
#  'Blackberry Brandy': 'spirit',
#  'Kummel': 'mixer',
#  'Brandy': 'spirit',
#  'Chocolate Ice-Cream': 'mixer',
#  'Cider': 'spirit',
#  'Whipped Cream': 'garnish',
#  'Tea Hot': 'mixer',
#  'Campari': 'spirit',
#  'Orange Peel': 'garnish',
#  'Sweet Vermouth Red': 'spirit',
#  'Apple Brandy': 'spirit',
#  'Allspice': 'garnish',
#  'Cinnamon': 'garnish',
#  'Apple Cider': 'spirit',
#  'Cloves': 'garnish',
#  'Brown Sugar': 'mixer',
#  'Apple Juice': 'mixer',
#  'Apple Schnapps': 'spirit',
#  'Benedictine': 'spirit',
#  'Green Ginger Wine': 'spirit',
#  'Candy': 'garnish',
#  'Grape Soda': 'mixer',
#  'Maui Blue': 'spirit',
#  'Mountain Dew': 'mixer',
#  'Green Creme De Menthe': 'spirit',
#  'Iced Tea Lemon': 'mixer',
#  'Pineapple': 'garnish',
#  'Cream Of Coconut': 'mixer',
#  'Gold Tequila': 'spirit',
#  'Lime Juice Cordial': 'mixer',
#  'Rye Whiskey': 'spirit',
#  'Red Wine': 'spirit',
#  'Tea': 'mixer',
#  'Passion Fruit Syrup': 'mixer',
#  'Crown Royal': 'spirit',
#  'Maraschino Liqueur': 'spirit',
#  'Sambuca': 'spirit',
#  'Banana': 'mixer',
#  'Prosecco': 'spirit',
#  'Galliano': 'spirit',
#  'Carbonated Water': 'mixer',
#  "Boone's Strawberry Hill Wine": 'spirit',
#  'Everclear': 'spirit',
#  'Kool-Aid Tropical Berry': 'mixer',
#  'Irish Cream': 'spirit',
#  'Ale': 'spirit',
#  'Guinness Stout': 'spirit',
#  'Cherry Brandy': 'spirit',
#  'Chocolate Syrup': 'mixer',
#  'Coffee Liqueur': 'mixer',
#  'Root Beer': 'mixer',
#  'Surge': 'mixer',
#  'Butterscotch Schnapps': 'spirit',
#  'Godiva Liqueur': 'spirit',
#  'Celery Salt': 'mixer',
#  'Tomato Juice': 'mixer',
#  'Tabasco Sauce': 'mixer',
#  'Worcestershire Sauce': 'mixer',
#  'Tia Maria': 'spirit',
#  'Caramel Sauce': 'mixer',
#  'Mini-Snickers Bars': 'mixer',
#  'Chocolate Sauce': 'mixer',
#  'Erin Cream': 'mixer',
#  'Advocaat': 'spirit',
#  'Sambuca White': 'spirit',
#  'Creme De Mure': 'spirit',
#  'Egg': 'mixer',
#  'Peachtree Schnapps': 'spirit',
#  'Banana Liqueur': 'spirit',
#  'Corona': 'spirit',
#  'Bacardi Limon': 'spirit',
#  'Cachaca': 'spirit',
#  'White Rum': 'spirit',
#  'Egg Yolk': 'mixer',
#  'Cherry Grenadine': 'mixer',
#  'Port': 'spirit',
#  'Chocolate Liqueur': 'spirit',
#  'Chocolate Milk': 'mixer',
#  'Creme De Cacao': 'spirit',
#  'Wine Muscatel': 'spirit',
#  'Spiced Rum': 'spirit',
#  'Hot Damn': 'spirit',
#  'Whiskey': 'spirit',
#  'Demerara Sugar': 'mixer',
#  'Cherry Heering': 'spirit',
#  'Peach Bitters': 'spirit',
#  'Blackcurrant Cordial': 'mixer',
#  'Olive': 'mixer',
#  'Olive Brine': 'mixer',
#  'Fruit Punch': 'mixer',
#  'Dubonnet Rouge': 'spirit',
#  'Pisco': 'spirit',
#  'Lavender': 'garnish',
#  'Pepper': 'garnish',
#  'Pineapple Syrup': 'mixer',
#  'St. Germain': 'mixer',
#  'Vanilla Extract': 'mixer',
#  'Whipping Cream': 'mixer',
#  'Condensed Milk Skimmed': 'mixer',
#  'Milk Skimmed': 'mixer',
#  'Firewater': 'spirit',
#  'Absolut Peppar': 'spirit',
#  'Dr. Pepper': 'mixer',
#  'Beer': 'spirit',
#  'Sarsaparilla': 'mixer',
#  'Raspberry Liqueur': 'spirit',
#  'Sirup Of Roses': 'mixer',
#  'Melon Liqueur': 'spirit',
#  'Orange Spiral': 'mixer',
#  'Agave Syrup': 'mixer',
#  'Whisky': 'spirit',
#  'Very Sweet Tea': 'mixer',
#  'Irish Whiskey': 'spirit',
#  'Iced Tea': 'mixer',
#  'Aperol': 'spirit',
#  'Peach Brandy': 'spirit',
#  'Tennessee Whiskey': 'spirit',
#  'Water Cold': 'mixer',
#  'Jello': 'mixer',
#  'Anisette': 'mixer',
#  'Green Chartreuse': 'spirit',
#  'Grain Alcohol': 'spirit',
#  'Apfelkorn': 'spirit',
#  'Cranberry Vodka': 'spirit',
#  'Kiwi Liqueur': 'spirit',
#  'Kool-Aid Tropical': 'mixer',
#  '151 Proof Rum Light': 'spirit',
#  'Kool-Aid Grape': 'mixer',
#  'Turkish Apple Tea': 'mixer',
#  'Drambuie': 'spirit',
#  'Orgeat Syrup': 'mixer',
#  'Tropicana': 'mixer',
#  'Bourbon Blended': 'spirit',
#  'Pina Colada Mix': 'mixer',
#  'Daiquiri Mix': 'mixer',
#  'Coffee Hazlenut': 'mixer',
#  'Cream Double': 'mixer',
#  'Cocoa Powder': 'mixer',
#  'Absinthe': 'spirit',
#  'Pepsi Cola': 'mixer',
#  'Lemon-Lime Soda': 'mixer',
#  'Oreo Cookie': 'mixer',
#  'Coconut Milk': 'mixer',
#  'Pink Lemonade': 'mixer',
#  'Cherry Liqueur': 'spirit',
#  'Raspberry Syrup': 'mixer',
#  'Sherry Cream': 'mixer',
#  'Coffee Brandy': 'spirit',
#  'Lime Vodka': 'spirit',
#  'Black Sambuca': 'spirit',
#  'Raspberry Vodka': 'spirit',
#  'Lime Peel': 'garnish',
#  'Fruit Punch Frozen': 'mixer',
#  'Apple': 'mixer',
#  'Ricard': 'spirit',
#  'Peychaud Bitters': 'spirit',
#  'Curacao': 'spirit',
#  'White Or Red Wine': 'spirit',
#  'Blackcurrant Squash': 'mixer',
#  'Berries': 'mixer',
#  'Ouzo': 'spirit',
#  'Aquavit': 'spirit',
#  'Yukon Jack': 'spirit',
#  'Maple Syrup': 'mixer',
#  'Lillet Blanc': 'spirit',
#  'Grape Juice Unsweetened': 'mixer',
#  'Half-And-Half': 'mixer',
#  'Limeade': 'mixer',
#  'Zima': 'spirit'}

# %%
from itertools import combinations
from collections import defaultdict

# Process the data to create ingredient pairs
ingredient_pairs = defaultdict(int)
ingredient_pairs_cocktails = defaultdict(list)

for drink in df['strDrink'].unique():
    ingredients = df[df['strDrink'] == drink]['strIngredients'].tolist()
    ingredients.sort()
    for pair in combinations(ingredients, 2):
        ingredient_pairs[pair] += 1
        ingredient_pairs_cocktails[pair].append(drink)

# Filter out pairs with a score less than or equal to 5
filtered_pairs = {pair: count for pair, count in ingredient_pairs.items() if count > 5}

# Recalculate the IDs for the filtered ingredients
filtered_ingredients = defaultdict(int)
for ing1, ing2 in filtered_pairs.keys():
    filtered_ingredients[ing1] += 1
    filtered_ingredients[ing2] += 1

filtered_ingredient_ids = {ingredient: idx for idx, ingredient in enumerate(filtered_ingredients)}

# Create a DataFrame for the network data
network_data = []
for pair, count in filtered_pairs.items():
    network_data.append({
        # "name1": pair[0],
        # "name2": pair[1],
        "from": filtered_ingredient_ids[pair[0]],
        "to": filtered_ingredient_ids[pair[1]],
        "value": count,
        "cocktails": list(set(ingredient_pairs_cocktails[pair]))
    })

# %%
ingredients_data = []
for idx, (ingredient, count) in enumerate(filtered_ingredients.items()):
    ingredients_data.append({
        'id':idx, 
        'value': count, 
        'label': ingredient, 
        'group': ingredients_type[ingredient]
    })

# %%
ingredients_data
# Out:
# [{'id': 0, 'value': 3, 'label': 'Orange Juice', 'group': 'mixer'},
#  {'id': 1, 'value': 9, 'label': 'Vodka', 'group': 'spirit'},
#  {'id': 2, 'value': 1, 'label': 'Bitters', 'group': 'spirit'},
#  {'id': 3, 'value': 16, 'label': 'Gin', 'group': 'spirit'},
#  {'id': 4, 'value': 11, 'label': 'Lemon', 'group': 'garnish'},
#  {'id': 5, 'value': 6, 'label': 'Triple Sec', 'group': 'spirit'},
#  {'id': 6, 'value': 5, 'label': 'Light Rum', 'group': 'spirit'},
#  {'id': 7, 'value': 2, 'label': 'Tequila', 'group': 'spirit'},
#  {'id': 8, 'value': 1, 'label': "Bailey'S Irish Cream", 'group': 'spirit'},
#  {'id': 9, 'value': 1, 'label': 'Kahlua', 'group': 'spirit'},
#  {'id': 10, 'value': 3, 'label': 'Grenadine', 'group': 'mixer'},
#  {'id': 11, 'value': 1, 'label': 'Cranberry Juice', 'group': 'mixer'},
#  {'id': 12, 'value': 1, 'label': 'Peach Schnapps', 'group': 'spirit'},
#  {'id': 13, 'value': 8, 'label': 'Lemon Juice', 'group': 'mixer'},
#  {'id': 14, 'value': 3, 'label': 'Cherry', 'group': 'garnish'},
#  {'id': 15, 'value': 4, 'label': 'Orange', 'group': 'garnish'},
#  {'id': 16, 'value': 1, 'label': 'Orange Bitters', 'group': 'spirit'},
#  {'id': 17, 'value': 1, 'label': 'Sweet Vermouth', 'group': 'spirit'},
#  {'id': 18, 'value': 2, 'label': 'Egg White', 'group': 'mixer'},
#  {'id': 19, 'value': 18, 'label': 'Sugar', 'group': 'garnish'},
#  {'id': 20, 'value': 3, 'label': 'Lime Juice', 'group': 'mixer'},
#  {'id': 21, 'value': 1, 'label': 'Rum', 'group': 'spirit'},
#  {'id': 22, 'value': 1, 'label': 'Lemonade', 'group': 'mixer'},
#  {'id': 23, 'value': 2, 'label': 'Water', 'group': 'mixer'},
#  {'id': 24, 'value': 1, 'label': 'Dry Vermouth', 'group': 'spirit'},
#  {'id': 25, 'value': 3, 'label': 'Lemon Peel', 'group': 'garnish'},
#  {'id': 26, 'value': 1, 'label': 'Light Cream', 'group': 'mixer'},
#  {'id': 27, 'value': 2, 'label': 'Nutmeg', 'group': 'garnish'},
#  {'id': 28, 'value': 1, 'label': 'Pineapple Juice', 'group': 'mixer'},
#  {'id': 29, 'value': 1, 'label': 'Maraschino Liqueur', 'group': 'spirit'},
#  {'id': 30, 'value': 3, 'label': 'Carbonated Water', 'group': 'mixer'},
#  {'id': 31, 'value': 4, 'label': 'Maraschino Cherry', 'group': 'garnish'},
#  {'id': 32, 'value': 2, 'label': 'Blended Whiskey', 'group': 'spirit'},
#  {'id': 33, 'value': 1, 'label': 'Bourbon', 'group': 'spirit'},
#  {'id': 34, 'value': 2, 'label': 'Brandy', 'group': 'spirit'},
#  {'id': 35, 'value': 1, 'label': 'Egg', 'group': 'mixer'},
#  {'id': 36, 'value': 2, 'label': 'Lime', 'group': 'garnish'}]

# %%
network_data
# Out:
# [{'from': 0,
#   'to': 1,
#   'value': 17,
#   'cocktails': ['Addison Special',
#    'Screwdriver',
#    'Orange Whip',
#    'Bubble Gum',
#    'Arctic Fish',
#    'Harvey Wallbanger',
#    'Irish Curdling Cow',
#    'After sex',
#    'Blue Mountain',
#    'Arizona Twister',
#    'Popped cherry',
#    'San Francisco',
#    'Orange Crush',
#    'Pink Penocha',
#    'Apricot punch',
#    "A Gilligan's Island",
#    '155 Belmont']},
#  {'from': 2,
#   'to': 3,
#   'value': 8,
#   'cocktails': ['Pink Gin',
#    'Turf Cocktail',
#    'Boomerang',
#    'Artillery',
#    'Bluebird',
#    'Gin Swizzle',
#    '3-Mile Long Island Iced Tea',
#    'Dubonnet Cocktail']},
#  {'from': 3,
#   'to': 4,
#   'value': 8,
#   'cocktails': ['Clover Club',
#    'Long Island Tea',
#    'Gin Rickey',
#    'Gin Fizz',
#    'Lady Love Fizz',
#    'Royal Gin Fizz',
#    'Gin Sling',
#    '3-Mile Long Island Iced Tea']},
#  {'from': 3,
#   'to': 5,
#   'value': 11,
#   'cocktails': ['Grass Skirt',
#    'White Lady',
#    'Boxcar',
#    'Cherry Electric Lemonade',
#    'Bluebird',
#    'Martinez Cocktail',
#    'Flying Dutchman',
#    'Waikiki Beachcomber',
#    'Hawaiian Cocktail',
#    'Radioactive Long Island Iced Tea',
#    '3-Mile Long Island Iced Tea']},
#  {'from': 3,
#   'to': 1,
#   'value': 10,
#   'cocktails': ['AT&T',
#    'Long Island Tea',
#    'Vesper',
#    'Army special',
#    'Cherry Electric Lemonade',
#    'Long Island Iced Tea',
#    'National Aquarium',
#    'Jitterbug',
#    'Radioactive Long Island Iced Tea',
#    '3-Mile Long Island Iced Tea']},
#  {'from': 4,
#   'to': 6,
#   'value': 8,
#   'cocktails': ['Long Island Tea',
#    "Quaker's Cocktail",
#    'Chicago Fizz',
#    'Vesuvio',
#    'Imperial Fizz',
#    'Shanghai Cocktail',
#    '3-Mile Long Island Iced Tea',
#    'Mississippi Planters Punch']},
#  {'from': 6,
#   'to': 5,
#   'value': 8,
#   'cocktails': ['Acapulco',
#    'Between The Sheets',
#    'Boston Sidecar',
#    'Apricot Lady',
#    'Frozen Daiquiri',
#    '3-Mile Long Island Iced Tea',
#    'Banana Daiquiri',
#    'Mai Tai']},
#  {'from': 7,
#   'to': 5,
#   'value': 7,
#   'cocktails': ['Adam Bomb',
#    'Strawberry Margarita',
#    'Margarita',
#    'Cherry Electric Lemonade',
#    "Gideon's Green Dinosaur",
#    '3-Mile Long Island Iced Tea',
#    'Radioactive Long Island Iced Tea']},
#  {'from': 7,
#   'to': 1,
#   'value': 7,
#   'cocktails': ['Long Island Tea',
#    'Adam Bomb',
#    'Cherry Electric Lemonade',
#    'Long Island Iced Tea',
#    "Gideon's Green Dinosaur",
#    '3-Mile Long Island Iced Tea',
#    'Radioactive Long Island Iced Tea']},
#  {'from': 5,
#   'to': 1,
#   'value': 10,
#   'cocktails': ['Adam Bomb',
#    'Atomic Lokade',
#    'Kool-Aid Shot',
#    'Cherry Electric Lemonade',
#    'Kamikaze',
#    'Orange Crush',
#    "Gideon's Green Dinosaur",
#    '3-Mile Long Island Iced Tea',
#    'Radioactive Long Island Iced Tea',
#    'Orgasm']},
#  {'from': 8,
#   'to': 9,
#   'value': 14,
#   'cocktails': ['Flaming Lamborghini',
#    'B-52',
#    'After Five',
#    'Dirty Nipple',
#    '747',
#    'Quick F**K',
#    'Midnight Manx',
#    'Screaming Orgasm',
#    'Baby Guinness',
#    'Afternoon',
#    'Blind Russian',
#    'Bumble Bee #1',
#    "Bruce's Puce",
#    'Oreo Mudslide']},
#  {'from': 10,
#   'to': 0,
#   'value': 9,
#   'cocktails': ['Addison Special',
#    'Orange Push-up',
#    'Tequila Sunrise',
#    'Space Odyssey',
#    'Arizona Twister',
#    'San Francisco',
#    'A Day at the Beach',
#    'Monkey Gland',
#    'Amaretto Sunrise']},
#  {'from': 11,
#   'to': 1,
#   'value': 11,
#   'cocktails': ['Sea breeze',
#    'Absolutely Fabulous',
#    'Bruised Heart',
#    'Kool-Aid Shot',
#    'Sex on the Beach',
#    'Cosmopolitan Martini',
#    'Absolut Stress #2',
#    'Popped cherry',
#    'Pink Penocha',
#    "A Gilligan's Island",
#    'Absolutely Cranberry Smash']},
#  {'from': 12,
#   'to': 1,
#   'value': 6,
#   'cocktails': ['Bubble Gum',
#    'Sex on the Beach',
#    'Absolut Stress #2',
#    'Bellini Martini',
#    'Pink Penocha',
#    "A Gilligan's Island"]},
#  {'from': 13,
#   'to': 6,
#   'value': 6,
#   'cocktails': ['Havana Cocktail',
#    'Rum Sour',
#    'Apricot Lady',
#    'A Night In Old Mandalay',
#    'Between The Sheets',
#    'Van Vleet']},
#  {'from': 3,
#   'to': 10,
#   'value': 15,
#   'cocktails': ['Clover Club',
#    'Grass Skirt',
#    'Gin Rickey',
#    'Gin Squirt',
#    'A1',
#    'Ace',
#    'Boxcar',
#    'Pink Lady',
#    'Gin Daisy',
#    'Rose',
#    'Monkey Gland',
#    'Singapore Sling',
#    'Jitterbug',
#    'English Rose Cocktail',
#    'Ruby Tuesday']},
#  {'from': 3,
#   'to': 13,
#   'value': 15,
#   'cocktails': ['Adam & Eve',
#    'White Lady',
#    'A1',
#    'Casino Royale',
#    'French 75',
#    'Arthur Tompkins',
#    'Boxcar',
#    'Gin Daisy',
#    'Rose',
#    'Aviation',
#    'Casino',
#    'English Rose Cocktail',
#    'Gin Sour',
#    'Bramble',
#    'Tom Collins']},
#  {'from': 10,
#   'to': 13,
#   'value': 7,
#   'cocktails': ['Adam',
#    'A1',
#    'Boxcar',
#    'Gin Daisy',
#    'Rose',
#    'Tequila Fizz',
#    'English Rose Cocktail']},
#  {'from': 14,
#   'to': 3,
#   'value': 7,
#   'cocktails': ['Abbey Cocktail',
#    'Gin Smash',
#    'Martinez Cocktail',
#    'Casino',
#    'Tuxedo Cocktail',
#    'Singapore Sling',
#    'English Rose Cocktail']},
#  {'from': 3,
#   'to': 15,
#   'value': 6,
#   'cocktails': ['Abbey Cocktail',
#    'French 75',
#    'Gin Smash',
#    'Gin Daisy',
#    'Gin Sour',
#    'Tom Collins']},
#  {'from': 3,
#   'to': 16,
#   'value': 7,
#   'cocktails': ['London Town',
#    'Abbey Cocktail',
#    'Casino Royale',
#    'Alaska Cocktail',
#    'Martinez Cocktail',
#    'Casino',
#    'Tuxedo Cocktail']},
#  {'from': 3,
#   'to': 17,
#   'value': 7,
#   'cocktails': ['Abbey Martini',
#    'Lone Tree Cocktail',
#    "Gentleman's Club",
#    'Negroni',
#    'Artillery',
#    'English Highball',
#    'Victor']},
#  {'from': 18,
#   'to': 19,
#   'value': 8,
#   'cocktails': ['Acapulco',
#    'Egg Nog #4',
#    'Lady Love Fizz',
#    'Boston Sour',
#    'Japanese Fizz',
#    'Vesuvio',
#    'Chicago Fizz']},
#  {'from': 6,
#   'to': 20,
#   'value': 7,
#   'cocktails': ['Bacardi Cocktail',
#    'Acapulco',
#    'Frozen Daiquiri',
#    'Strawberry Daiquiri',
#    'Banana Daiquiri',
#    'Frozen Mint Daiquiri',
#    'Frozen Pineapple Daiquiri']},
#  {'from': 6,
#   'to': 19,
#   'value': 17,
#   'cocktails': ['Mississippi Planters Punch',
#    'Acapulco',
#    'Mojito',
#    'Rum Milk Punch',
#    'Egg Nog #4',
#    'Daiquiri',
#    'Rum Sour',
#    'Frozen Daiquiri',
#    'Strawberry Daiquiri',
#    'Vesuvio',
#    'Rum Old-fashioned',
#    'Imperial Fizz',
#    'Chicago Fizz',
#    'Banana Daiquiri',
#    'Frozen Mint Daiquiri',
#    'Frozen Pineapple Daiquiri']},
#  {'from': 20,
#   'to': 19,
#   'value': 8,
#   'cocktails': ['Acapulco',
#    'Frozen Daiquiri',
#    'Strawberry Daiquiri',
#    'Gin Swizzle',
#    'Jitterbug',
#    'Banana Daiquiri',
#    'Frozen Mint Daiquiri',
#    'Frozen Pineapple Daiquiri']},
#  {'from': 20,
#   'to': 5,
#   'value': 6,
#   'cocktails': ['Acapulco',
#    'Margarita',
#    'Frozen Daiquiri',
#    'Yellow Bird',
#    'Kamikaze',
#    'Banana Daiquiri']},
#  {'from': 21,
#   'to': 1,
#   'value': 6,
#   'cocktails': ['Adam Bomb',
#    'Orange Whip',
#    'Aztec Punch',
#    'National Aquarium',
#    'Brain Fart',
#    'Radioactive Long Island Iced Tea']},
#  {'from': 22,
#   'to': 1,
#   'value': 6,
#   'cocktails': ['Aztec Punch',
#    'Atomic Lokade',
#    'Shark Attack',
#    'Avalon',
#    'Adam Sunrise',
#    'Blue Lagoon']},
#  {'from': 19,
#   'to': 23,
#   'value': 11,
#   'cocktails': ['Mulled Wine',
#    'Old Fashioned',
#    'Gin Toddy',
#    'Rum Toddy',
#    'Rum Old-fashioned',
#    'Adam Sunrise',
#    'Gluehwein',
#    'Bourbon Sling',
#    'Gin Sling',
#    'Sazerac',
#    'Classic Old-Fashioned']},
#  {'from': 24,
#   'to': 3,
#   'value': 12,
#   'cocktails': ['Lone Tree Cooler',
#    'Turf Cocktail',
#    'Boomerang',
#    'Queen Elizabeth',
#    'Bermuda Highball',
#    'Martinez Cocktail',
#    'Rose',
#    'Tuxedo Cocktail',
#    'Allies Cocktail',
#    'English Rose Cocktail',
#    'Adios Amigos Cocktail',
#    'Martini']},
#  {'from': 13,
#   'to': 5,
#   'value': 8,
#   'cocktails': ['White Lady',
#    'Strawberry Margarita',
#    'Applecar',
#    'After Supper Cocktail',
#    'Boxcar',
#    'Apricot Lady',
#    'City Slicker',
#    'Between The Sheets']},
#  {'from': 3,
#   'to': 25,
#   'value': 10,
#   'cocktails': ['Lone Tree Cooler',
#    'Gin Toddy',
#    'Arthur Tompkins',
#    'Alaska Cocktail',
#    'Bermuda Highball',
#    'Bluebird',
#    'English Highball',
#    'Long Island Iced Tea',
#    'Dubonnet Cocktail',
#    'Gin Cooler']},
#  {'from': 26,
#   'to': 27,
#   'value': 6,
#   'cocktails': ['Port Wine Flip',
#    'Alexander',
#    'Brandy Flip',
#    'Brandy Alexander',
#    'Quentin',
#    'Sherry Flip']},
#  {'from': 13,
#   'to': 15,
#   'value': 9,
#   'cocktails': ['Victory Collins',
#    'French 75',
#    'Bourbon Sour',
#    'Apricot Lady',
#    'Rum Sour',
#    'Gin Daisy',
#    'Gin Sour',
#    'John Collins',
#    'Tom Collins']},
#  {'from': 0,
#   'to': 28,
#   'value': 6,
#   'cocktails': ["Planter's Punch",
#    'Space Odyssey',
#    'Sunny Holiday Punch',
#    'Rum Runner',
#    'Arizona Twister',
#    'Wine Punch']},
#  {'from': 13,
#   'to': 1,
#   'value': 7,
#   'cocktails': ['Victory Collins',
#    'Blue Mountain',
#    'Avalon',
#    'Bloody Mary',
#    'Ice Pick #1',
#    'Brain Fart',
#    'Russian Spring Punch']},
#  {'from': 3,
#   'to': 29,
#   'value': 6,
#   'cocktails': ['London Town',
#    'Casino Royale',
#    'Boomerang',
#    'Aviation',
#    'Casino',
#    'Tuxedo Cocktail']},
#  {'from': 14,
#   'to': 19,
#   'value': 9,
#   'cocktails': ['Tequila Sour',
#    'Scotch Sour',
#    'New York Sour',
#    'Boston Sour',
#    'Gin Smash',
#    'Frozen Daiquiri',
#    'Whiskey Sour',
#    'Brandy Sour',
#    'Banana Daiquiri']},
#  {'from': 30,
#   'to': 3,
#   'value': 10,
#   'cocktails': ['Gin Squirt',
#    'Lone Tree Cooler',
#    'Gin Fizz',
#    'Lady Love Fizz',
#    'Gin Smash',
#    'Royal Gin Fizz',
#    'Bermuda Highball',
#    'English Highball',
#    'Singapore Sling',
#    'Gin Cooler']},
#  {'from': 3,
#   'to': 31,
#   'value': 6,
#   'cocktails': ['French 75',
#    'Boomerang',
#    'Gin Daisy',
#    'Bluebird',
#    'Gin Sour',
#    'Tom Collins']},
#  {'from': 32,
#   'to': 4,
#   'value': 11,
#   'cocktails': ['New York Sour',
#    'Boston Sour',
#    'Japanese Fizz',
#    'Whiskey Sour',
#    'California Lemonade',
#    'Imperial Fizz',
#    'Frisco Sour']},
#  {'from': 32,
#   'to': 19,
#   'value': 6,
#   'cocktails': ['New York Sour',
#    'Boston Sour',
#    'Japanese Fizz',
#    'Whiskey Sour',
#    'California Lemonade',
#    'Imperial Fizz']},
#  {'from': 14,
#   'to': 4,
#   'value': 11,
#   'cocktails': ['Tequila Sour',
#    'Scotch Sour',
#    'New York Sour',
#    'Boston Sour',
#    'Whiskey Sour',
#    'Brandy Sour']},
#  {'from': 18,
#   'to': 4,
#   'value': 7,
#   'cocktails': ['Clover Club',
#    'Lady Love Fizz',
#    'Boston Sour',
#    'Japanese Fizz',
#    'Vesuvio',
#    'Chicago Fizz']},
#  {'from': 4,
#   'to': 4,
#   'value': 6,
#   'cocktails': ['Tequila Sour',
#    'New York Sour',
#    'Boston Sour',
#    'Whiskey Sour',
#    'Brandy Sour',
#    'Frisco Sour']},
#  {'from': 4,
#   'to': 19,
#   'value': 25,
#   'cocktails': ['Brandy Sour',
#    'Scotch Sour',
#    'Royal Gin Fizz',
#    'Rum Cobbler',
#    'Whiskey Sour',
#    'Chicago Fizz',
#    'Lemon Shot',
#    'Gin Fizz',
#    'Lady Love Fizz',
#    'Boston Sour',
#    'Japanese Fizz',
#    'California Lemonade',
#    'Brandy Cobbler',
#    'New York Sour',
#    'Vesuvio',
#    'Imperial Fizz',
#    'Gin Sling',
#    'Tequila Sour',
#    "Sangria - The World's Best",
#    'Mississippi Planters Punch']},
#  {'from': 33,
#   'to': 19,
#   'value': 9,
#   'cocktails': ['Old Fashioned',
#    'Egg Nog #4',
#    'Bourbon Sour',
#    'Bourbon Sling',
#    'John Collins',
#    'Sazerac',
#    'Mississippi Planters Punch',
#    'Classic Old-Fashioned']},
#  {'from': 13,
#   'to': 19,
#   'value': 12,
#   'cocktails': ['Victory Collins',
#    'Pisco Sour',
#    'French 75',
#    'Bourbon Sour',
#    'Rum Sour',
#    'Sangria #1',
#    'Gin Daisy',
#    'Rose',
#    'Bourbon Sling',
#    'Gin Sour',
#    'John Collins',
#    'Tom Collins']},
#  {'from': 25,
#   'to': 19,
#   'value': 9,
#   'cocktails': ['Lone Tree Cooler',
#    'Mulled Wine',
#    'Champagne Cocktail',
#    'Gin Toddy',
#    'Rum Toddy',
#    'Gluehwein',
#    'Bourbon Sling',
#    'Sazerac',
#    'Gin Cooler']},
#  {'from': 25,
#   'to': 23,
#   'value': 6,
#   'cocktails': ['Mulled Wine',
#    'Gin Toddy',
#    'Rum Toddy',
#    'Gluehwein',
#    'Bourbon Sling',
#    'Sazerac']},
#  {'from': 13,
#   'to': 31,
#   'value': 7,
#   'cocktails': ['French 75',
#    'Bourbon Sour',
#    'Rum Sour',
#    'Gin Daisy',
#    'Gin Sour',
#    'John Collins',
#    'Tom Collins']},
#  {'from': 31,
#   'to': 15,
#   'value': 10,
#   'cocktails': ['Brandy Cobbler',
#    'French 75',
#    'Bourbon Sour',
#    'Rum Sour',
#    'Gin Daisy',
#    'Rum Cobbler',
#    'Gin Sour',
#    'John Collins',
#    'Tom Collins',
#    'Classic Old-Fashioned']},
#  {'from': 31,
#   'to': 19,
#   'value': 10,
#   'cocktails': ['Brandy Cobbler',
#    'French 75',
#    'Bourbon Sour',
#    'Rum Sour',
#    'Gin Daisy',
#    'Rum Cobbler',
#    'Gin Sour',
#    'John Collins',
#    'Tom Collins',
#    'Classic Old-Fashioned']},
#  {'from': 15,
#   'to': 19,
#   'value': 13,
#   'cocktails': ['Victory Collins',
#    'Brandy Cobbler',
#    'French 75',
#    'Bourbon Sour',
#    'Gin Smash',
#    'Rum Sour',
#    'Gin Daisy',
#    'Rum Cobbler',
#    "Sangria - The World's Best",
#    'Gin Sour',
#    'John Collins',
#    'Tom Collins',
#    'Classic Old-Fashioned']},
#  {'from': 34,
#   'to': 4,
#   'value': 7,
#   'cocktails': ['Brandy Cobbler',
#    'Sidecar Cocktail',
#    "Quaker's Cocktail",
#    "Sangria - The World's Best",
#    'Brandy Sour',
#    'Mississippi Planters Punch']},
#  {'from': 34,
#   'to': 19,
#   'value': 6,
#   'cocktails': ['Brandy Cobbler',
#    'Mulled Wine',
#    'Brandy Flip',
#    "Sangria - The World's Best",
#    'Brandy Sour',
#    'Mississippi Planters Punch']},
#  {'from': 35,
#   'to': 19,
#   'value': 7,
#   'cocktails': ['Port Wine Flip',
#    'Sherry Flip',
#    'Royal Gin Fizz',
#    'Egg Nog - Healthy',
#    'Brandy Flip',
#    'Egg-Nog - Classic Cooked',
#    'Sherry Eggnog']},
#  {'from': 27,
#   'to': 19,
#   'value': 8,
#   'cocktails': ['Port Wine Flip',
#    'Rum Milk Punch',
#    'Egg Nog #4',
#    'Sherry Flip',
#    'Egg Nog - Healthy',
#    'Brandy Flip',
#    'Sherry Eggnog']},
#  {'from': 36,
#   'to': 19,
#   'value': 6,
#   'cocktails': ['Mojito',
#    'Scotch Sour',
#    'Daiquiri',
#    'Caipirinha',
#    'California Lemonade',
#    'Caipirissima']},
#  {'from': 30,
#   'to': 4,
#   'value': 8,
#   'cocktails': ['Gin Fizz',
#    'Lady Love Fizz',
#    'Japanese Fizz',
#    'Royal Gin Fizz',
#    'Chicago Fizz',
#    'California Lemonade',
#    'Imperial Fizz',
#    'Mississippi Planters Punch']},
#  {'from': 30,
#   'to': 19,
#   'value': 12,
#   'cocktails': ['Mississippi Planters Punch',
#    'Gin Squirt',
#    'Lone Tree Cooler',
#    'Gin Fizz',
#    'Lady Love Fizz',
#    'Gin Smash',
#    'Japanese Fizz',
#    'Royal Gin Fizz',
#    'California Lemonade',
#    'Imperial Fizz',
#    'Chicago Fizz',
#    'Gin Cooler']},
#  {'from': 4,
#   'to': 36,
#   'value': 7,
#   'cocktails': ['Gin Rickey',
#    'Frisco Sour',
#    'California Lemonade',
#    'Scotch Sour']},
#  {'from': 3,
#   'to': 19,
#   'value': 16,
#   'cocktails': ['Gin Squirt',
#    'Lone Tree Cooler',
#    'Tom Collins',
#    'Gin Fizz',
#    'Lady Love Fizz',
#    'French 75',
#    'Gin Smash',
#    'Gin Toddy',
#    'Royal Gin Fizz',
#    'Gin Daisy',
#    'Rose',
#    'Gin Swizzle',
#    'Gin Sour',
#    'Jitterbug',
#    'Gin Sling',
#    'Gin Cooler']}]

# %%
import json
with open("nodes.json", "w") as json_file:
    json.dump(ingredients_data, json_file, indent=4)
with open("edges.json", "w") as json_file:
    json.dump(network_data, json_file, indent=4)

# %% [markdown]
# # Previous version

# %%
from itertools import combinations
from collections import defaultdict

# Process the data to create ingredient pairs
ingredient_pairs = defaultdict(int)
ingredient_pairs_cocktails = defaultdict(list)

for drink in df['strDrink'].unique():
    ingredients = df[df['strDrink'] == drink]['strIngredients'].tolist()
    try:
        ingredients.remove('Sugar')
    except Exception:
        pass
    ingredients.sort()
    for pair in combinations(ingredients, 2):
        ingredient_pairs[pair] += 1
        ingredient_pairs_cocktails[pair].append(drink)

# Filter out pairs with a score less than or equal to 5
filtered_pairs = {pair: count for pair, count in ingredient_pairs.items() if count > 5}

# Recalculate the IDs for the filtered ingredients
filtered_ingredients = defaultdict(int)
for ing1, ing2 in filtered_pairs.keys():
    filtered_ingredients[ing1] += 1
    filtered_ingredients[ing2] += 1

filtered_ingredient_ids = {ingredient: idx for idx, ingredient in enumerate(filtered_ingredients)}

# # Assign unique IDs to each ingredient
# unique_ingredients = set(df['strIngredients'])
# ingredient_ids = {ingredient: idx for idx, ingredient in enumerate(unique_ingredients)}

# Create a DataFrame for the network data
network_data = []
for pair, count in filtered_pairs.items():
    network_data.append({
        "name1": pair[0],
        "name2": pair[1],
        "score": count,
        "source": filtered_ingredient_ids[pair[0]],
        "target": filtered_ingredient_ids[pair[1]],
        "cocktails": ingredient_pairs_cocktails[pair]
    })

network_df = pd.DataFrame(network_data)

# Displaying the first few rows of the network data
network_df.sort_values(by='score', ascending=False)
# Out:
#                    name1               name2  score  source  target  \
# 0           Orange Juice               Vodka     17       0       1
# 16                   Gin         Lemon Juice     15       3      13
# 15                   Gin           Grenadine     15       3      10
# 10  Bailey'S Irish Cream              Kahlua     14       8       9
# 26          Dry Vermouth                 Gin     12      21       3
# 12       Cranberry Juice               Vodka     11      11       1
# 3                    Gin          Triple Sec     11       3       5
# 36       Blended Whiskey               Lemon     11      29       4
# 37                Cherry               Lemon     11      14       4
# 28                   Gin          Lemon Peel     10       3      22
# 34      Carbonated Water                 Gin     10      27       3
# 42     Maraschino Cherry              Orange     10      28      15
# 9             Triple Sec               Vodka     10       5       1
# 4                    Gin               Vodka     10       3       1
# 11             Grenadine        Orange Juice      9      10       0
# 30           Lemon Juice              Orange      9      13      15
# 44      Carbonated Water               Lemon      8      27       4
# 6              Light Rum          Triple Sec      8       6       5
# 5                  Lemon           Light Rum      8       4       6
# 1                Bitters                 Gin      8       2       3
# 2                    Gin               Lemon      8       3       4
# 27           Lemon Juice          Triple Sec      8      13       5
# 41           Lemon Juice   Maraschino Cherry      7      13      28
# 43                Brandy               Lemon      7      32       4
# 38             Egg White               Lemon      7      30       4
# 32           Lemon Juice               Vodka      7      13       1
# 45                 Lemon                Lime      7       4      33
# 7                Tequila          Triple Sec      7       7       5
# 22             Light Rum          Lime Juice      7       6      18
# 8                Tequila               Vodka      7       7       1
# 21                   Gin      Sweet Vermouth      7       3      17
# 20                   Gin      Orange Bitters      7       3      16
# 18                Cherry                 Gin      7      14       3
# 17             Grenadine         Lemon Juice      7      10      13
# 25              Lemonade               Vodka      6      20       1
# 39                 Lemon               Lemon      6       4       4
# 13        Peach Schnapps               Vodka      6      12       1
# 14           Lemon Juice           Light Rum      6      13       6
# 40            Lemon Peel               Water      6      22      31
# 19                   Gin              Orange      6       3      15
# 24                   Rum               Vodka      6      19       1
# 35                   Gin   Maraschino Cherry      6       3      28
# 33                   Gin  Maraschino Liqueur      6       3      26
# 31          Orange Juice     Pineapple Juice      6       0      25
# 29           Light Cream              Nutmeg      6      23      24
# 23            Lime Juice          Triple Sec      6      18       5
#
#                                             cocktails
# 0   [155 Belmont, A Gilligan's Island, Addison Spe...
# 16  [A1, Adam & Eve, Arthur Tompkins, Aviation, Bo...
# 15  [A1, Ace, Boxcar, Clover Club, English Rose Co...
# 10  [747, After Five, Afternoon, B-52, Baby Guinne...
# 26  [Adios Amigos Cocktail, Allies Cocktail, Bermu...
# 12  [A Gilligan's Island, Absolut Stress #2, Absol...
# 3   [3-Mile Long Island Iced Tea, Bluebird, Boxcar...
# 36  [Boston Sour, Boston Sour, California Lemonade...
# 37  [Boston Sour, Boston Sour, Brandy Sour, Brandy...
# 28  [Alaska Cocktail, Arthur Tompkins, Bermuda Hig...
# 34  [Bermuda Highball, English Highball, Gin Coole...
# 42  [Bourbon Sour, Brandy Cobbler, Classic Old-Fas...
# 9   [3-Mile Long Island Iced Tea, Adam Bomb, Atomi...
# 4   [3-Mile Long Island Iced Tea, AT&T, Army speci...
# 11  [A Day at the Beach, Addison Special, Amaretto...
# 30  [Apricot Lady, Bourbon Sour, French 75, Gin Da...
# 44  [California Lemonade, Chicago Fizz, Gin Fizz, ...
# 6   [3-Mile Long Island Iced Tea, Acapulco, Aprico...
# 5   [3-Mile Long Island Iced Tea, Chicago Fizz, Im...
# 1   [3-Mile Long Island Iced Tea, Artillery, Blueb...
# 2   [3-Mile Long Island Iced Tea, Clover Club, Gin...
# 27  [After Supper Cocktail, Applecar, Apricot Lady...
# 41  [Bourbon Sour, French 75, Gin Daisy, Gin Sour,...
# 43  [Brandy Cobbler, Brandy Sour, Brandy Sour, Mis...
# 38  [Boston Sour, Boston Sour, Chicago Fizz, Clove...
# 32  [Avalon, Bloody Mary, Blue Mountain, Brain Far...
# 45  [California Lemonade, Frisco Sour, Frisco Sour...
# 7   [3-Mile Long Island Iced Tea, Adam Bomb, Cherr...
# 22  [Acapulco, Bacardi Cocktail, Banana Daiquiri, ...
# 8   [3-Mile Long Island Iced Tea, Adam Bomb, Cherr...
# 21  [Abbey Martini, Artillery, English Highball, G...
# 20  [Abbey Cocktail, Alaska Cocktail, Casino, Casi...
# 18  [Abbey Cocktail, Casino, English Rose Cocktail...
# 17  [A1, Adam, Boxcar, English Rose Cocktail, Gin ...
# 25  [Adam Sunrise, Atomic Lokade, Avalon, Aztec Pu...
# 39  [Boston Sour, Brandy Sour, Frisco Sour, New Yo...
# 13  [A Gilligan's Island, Absolut Stress #2, Belli...
# 14  [A Night In Old Mandalay, Apricot Lady, Betwee...
# 40  [Bourbon Sling, Gin Toddy, Gluehwein, Mulled W...
# 19  [Abbey Cocktail, French 75, Gin Daisy, Gin Sma...
# 24  [Adam Bomb, Aztec Punch, Brain Fart, National ...
# 35  [Bluebird, Boomerang, French 75, Gin Daisy, Gi...
# 33  [Aviation, Boomerang, Casino, Casino Royale, L...
# 31  [Arizona Twister, Planter's Punch, Rum Runner,...
# 29  [Alexander, Brandy Alexander, Brandy Flip, Por...
# 23  [Acapulco, Banana Daiquiri, Frozen Daiquiri, K...

# %%
network_df.to_csv('ingredient_relationships.csv', index=False)

# %%
filtered_ingredients
# Out:
# defaultdict(int,
#             {'Orange Juice': 3,
#              'Vodka': 9,
#              'Bitters': 1,
#              'Gin': 15,
#              'Lemon': 10,
#              'Triple Sec': 6,
#              'Light Rum': 4,
#              'Tequila': 2,
#              "Bailey'S Irish Cream": 1,
#              'Kahlua': 1,
#              'Grenadine': 3,
#              'Cranberry Juice': 1,
#              'Peach Schnapps': 1,
#              'Lemon Juice': 7,
#              'Cherry': 2,
#              'Orange': 3,
#              'Orange Bitters': 1,
#              'Sweet Vermouth': 1,
#              'Lime Juice': 2,
#              'Rum': 1,
#              'Lemonade': 1,
#              'Dry Vermouth': 1,
#              'Lemon Peel': 2,
#              'Light Cream': 1,
#              'Nutmeg': 1,
#              'Pineapple Juice': 1,
#              'Maraschino Liqueur': 1,
#              'Carbonated Water': 2,
#              'Maraschino Cherry': 3,
#              'Blended Whiskey': 1,
#              'Egg White': 1,
#              'Water': 1,
#              'Brandy': 1,
#              'Lime': 1})

# %%
ingredients_data = {'nameDisplay': filtered_ingredients.keys(), 'name': filtered_ingredients.keys(), 'count': filtered_ingredients.values()}
ingredients_df = pd.DataFrame.from_dict(ingredients_data)

# %%
ingredients_df.to_csv('network_ingredients.csv', index=False)

# %%
ingredients_df
# Out:
#              nameDisplay                  name  count
# 0           Orange Juice          Orange Juice      3
# 1                  Vodka                 Vodka      9
# 2                Bitters               Bitters      1
# 3                    Gin                   Gin     15
# 4                  Lemon                 Lemon     10
# 5             Triple Sec            Triple Sec      6
# 6              Light Rum             Light Rum      4
# 7                Tequila               Tequila      2
# 8   Bailey'S Irish Cream  Bailey'S Irish Cream      1
# 9                 Kahlua                Kahlua      1
# 10             Grenadine             Grenadine      3
# 11       Cranberry Juice       Cranberry Juice      1
# 12        Peach Schnapps        Peach Schnapps      1
# 13           Lemon Juice           Lemon Juice      7
# 14                Cherry                Cherry      2
# 15                Orange                Orange      3
# 16        Orange Bitters        Orange Bitters      1
# 17        Sweet Vermouth        Sweet Vermouth      1
# 18            Lime Juice            Lime Juice      2
# 19                   Rum                   Rum      1
# 20              Lemonade              Lemonade      1
# 21          Dry Vermouth          Dry Vermouth      1
# 22            Lemon Peel            Lemon Peel      2
# 23           Light Cream           Light Cream      1
# 24                Nutmeg                Nutmeg      1
# 25       Pineapple Juice       Pineapple Juice      1
# 26    Maraschino Liqueur    Maraschino Liqueur      1
# 27      Carbonated Water      Carbonated Water      2
# 28     Maraschino Cherry     Maraschino Cherry      3
# 29       Blended Whiskey       Blended Whiskey      1
# 30             Egg White             Egg White      1
# 31                 Water                 Water      1
# 32                Brandy                Brandy      1
# 33                  Lime                  Lime      1

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=08e32eae-680f-4766-bfea-eabbd1bdf534' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
